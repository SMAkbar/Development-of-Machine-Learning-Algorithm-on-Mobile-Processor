# %%
import numpy as np

eval_data_original = np.load("/content/drive/MyDrive/Colab Notebooks/eval_data_complete.npy")
eval_label_original = np.load("/content/drive/MyDrive/Colab Notebooks/eval_label_complete.npy")

# %%
eval_data = eval_data_original[10:-50]
eval_label = eval_label_original[10:-50]

test_data = np.concatenate((eval_data_original[:10], eval_data_original[-50:]))
test_label = np.concatenate((eval_label_original[:10], eval_label_original[-50:]))

eval_data_original = 0
eval_label_original = 0

# %%
eval_data = np.concatenate((eval_data[:337], eval_data[:337], eval_data[:337], eval_data[:337], eval_data))
eval_label = np.concatenate((eval_label[:337], eval_label[:337], eval_label[:337], eval_label[:337], eval_label))
print(eval_data.shape)
print(eval_label.shape)
# Out:
# (3483, 22, 15000)
# (3483,)

# %%
idx = np.random.permutation(len(eval_data))
eval_data,eval_label = eval_data[idx], eval_label[idx]
idx = 0

# %%
from tensorflow.keras.utils import to_categorical

enc_labels = to_categorical(eval_label, num_classes=2)              
eval_label= enc_labels
enc_labels = 0
print(eval_data.shape)
print(eval_label.shape)
print(eval_data.dtype)
print(eval_label.dtype)
print('training labels have been loaded')

bs,t,f = eval_data.shape
# Out:
# (3483, 22, 15000)
# (3483, 2)
# float32
# float32
# training labels have been loaded

# %%
from pdb import set_trace
#import mne
import pandas as pd
import numpy as np
import math
import os
import h5py
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,LSTM, Dense, Activation, Bidirectional
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import MaxPooling3D
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping


# ----------------------DEEP-NET Testing-----------------------
from tensorflow.keras.layers import Input,Dense,concatenate,Flatten,GRU,Conv1D,Conv2D
from tensorflow.keras.models import Model

inputsin= Input(shape=(t,f))


# ------------------First Inception
deep_net = Conv1D(25, 10, strides=1, activation='relu',padding="causal")(inputsin)
deep_net = MaxPooling1D(3, 3, padding="same")(deep_net)

deep_net = Conv1D(50, 10, activation='relu', padding='causal')(deep_net)
deep_net = MaxPooling1D(3, 3, padding='same')(deep_net)

deep_net = Conv1D(100, 10, activation='relu', padding='causal')(deep_net)
deep_net = MaxPooling1D(3, 3, padding='same')(deep_net)

deep_net = Conv1D(200, 10, activation='relu', padding='causal')(deep_net)
deep_net = MaxPooling1D(3, 3, padding='same')(deep_net)

deep_net = Flatten()(deep_net)
predictions = Dense(2,activation='softmax')(deep_net)


deep_model = Model(inputs=inputsin, outputs=predictions)

# learning rate to 0.00001
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001)

deep_model.compile(optimizer = adam_optimizer, loss = 'categorical_crossentropy', metrics=['accuracy'])
print(deep_model.metrics_names)
print(deep_model.summary())

# early stopping
es = EarlyStopping(monitor='val_loss', min_delta=0.01, mode='min', verbose=1, patience=25)                                # patience
mc = ModelCheckpoint('deep_model3flipped_acc.hdf5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)        # filepath (save model as)
mces = ModelCheckpoint('deep_model3flipped_loss.hdf5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)    # filepath (save model as)

# fit model
hist=deep_model.fit(eval_data,eval_label,validation_split=0.1, epochs=100,batch_size=64,verbose=1,callbacks=[es, mc,mces],shuffle=False) #epochs #split #
print('The End')
# Out:
# []
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 22, 15000)]       0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 22, 25)            3750025
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 8, 25)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 8, 50)             12550
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 3, 50)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 3, 100)            50100
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1, 100)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1, 200)            200200
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 200)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 200)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 402
# =================================================================
# Total params: 4,013,277
# Trainable params: 4,013,277
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 49/49 [==============================] - 36s 113ms/step - loss: 0.6896 - accuracy: 0.6203 - val_loss: 0.6796 - val_accuracy: 0.6991
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00001: val_loss improved from inf to 0.67958, saving model to deep_model3flipped_loss.hdf5
# Epoch 2/100
# 49/49 [==============================] - 3s 71ms/step - loss: 0.6649 - accuracy: 0.9365 - val_loss: 0.6627 - val_accuracy: 0.8052
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00002: val_loss improved from 0.67958 to 0.66275, saving model to deep_model3flipped_loss.hdf5
# Epoch 3/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.6358 - accuracy: 0.9894 - val_loss: 0.6368 - val_accuracy: 0.9026
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00003: val_loss improved from 0.66275 to 0.63675, saving model to deep_model3flipped_loss.hdf5
# Epoch 4/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.5924 - accuracy: 0.9961 - val_loss: 0.5974 - val_accuracy: 0.9513
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00004: val_loss improved from 0.63675 to 0.59735, saving model to deep_model3flipped_loss.hdf5
# Epoch 5/100
# 49/49 [==============================] - 3s 71ms/step - loss: 0.5308 - accuracy: 0.9963 - val_loss: 0.5426 - val_accuracy: 0.9828
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00005: val_loss improved from 0.59735 to 0.54255, saving model to deep_model3flipped_loss.hdf5
# Epoch 6/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.4511 - accuracy: 0.9981 - val_loss: 0.4735 - val_accuracy: 0.9885
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00006: val_loss improved from 0.54255 to 0.47347, saving model to deep_model3flipped_loss.hdf5
# Epoch 7/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.3599 - accuracy: 0.9982 - val_loss: 0.3970 - val_accuracy: 0.9943
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00007: val_loss improved from 0.47347 to 0.39702, saving model to deep_model3flipped_loss.hdf5
# Epoch 8/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.2711 - accuracy: 1.0000 - val_loss: 0.3251 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00008: val_loss improved from 0.39702 to 0.32508, saving model to deep_model3flipped_loss.hdf5
# Epoch 9/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.1971 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00009: val_loss improved from 0.32508 to 0.26402, saving model to deep_model3flipped_loss.hdf5
# Epoch 10/100
# 49/49 [==============================] - 3s 72ms/step - loss: 0.1416 - accuracy: 1.0000 - val_loss: 0.2160 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00010: val_loss improved from 0.26402 to 0.21598, saving model to deep_model3flipped_loss.hdf5
# Epoch 11/100
# 49/49 [==============================] - 3s 71ms/step - loss: 0.1024 - accuracy: 1.0000 - val_loss: 0.1794 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00011: val_loss improved from 0.21598 to 0.17942, saving model to deep_model3flipped_loss.hdf5
# Epoch 12/100
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0754 - accuracy: 1.0000 - val_loss: 0.1521 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00012: val_loss improved from 0.17942 to 0.15206, saving model to deep_model3flipped_loss.hdf5
# Epoch 13/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0568 - accuracy: 1.0000 - val_loss: 0.1313 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00013: val_loss improved from 0.15206 to 0.13135, saving model to deep_model3flipped_loss.hdf5
# Epoch 14/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.1154 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00014: val_loss improved from 0.13135 to 0.11536, saving model to deep_model3flipped_loss.hdf5
# Epoch 15/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.1027 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00015: val_loss improved from 0.11536 to 0.10274, saving model to deep_model3flipped_loss.hdf5
# Epoch 16/100
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00016: val_loss improved from 0.10274 to 0.09253, saving model to deep_model3flipped_loss.hdf5
# Epoch 17/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.0842 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00017: val_loss improved from 0.09253 to 0.08415, saving model to deep_model3flipped_loss.hdf5
# Epoch 18/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.0772 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00018: val_loss improved from 0.08415 to 0.07721, saving model to deep_model3flipped_loss.hdf5
# Epoch 19/100
# 49/49 [==============================] - 3s 72ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00019: val_loss improved from 0.07721 to 0.07134, saving model to deep_model3flipped_loss.hdf5
# Epoch 20/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0126 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00020: val_loss improved from 0.07134 to 0.06634, saving model to deep_model3flipped_loss.hdf5
# Epoch 21/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0620 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00021: val_loss improved from 0.06634 to 0.06204, saving model to deep_model3flipped_loss.hdf5
# Epoch 22/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00022: val_loss improved from 0.06204 to 0.05831, saving model to deep_model3flipped_loss.hdf5
# Epoch 23/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00023: val_loss improved from 0.05831 to 0.05504, saving model to deep_model3flipped_loss.hdf5
# Epoch 24/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0521 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00024: val_loss improved from 0.05504 to 0.05215, saving model to deep_model3flipped_loss.hdf5
# Epoch 25/100
# 49/49 [==============================] - 3s 70ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00025: val_loss improved from 0.05215 to 0.04960, saving model to deep_model3flipped_loss.hdf5
# Epoch 26/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00026: val_loss improved from 0.04960 to 0.04731, saving model to deep_model3flipped_loss.hdf5
# Epoch 27/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0453 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00027: val_loss improved from 0.04731 to 0.04526, saving model to deep_model3flipped_loss.hdf5
# Epoch 28/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0434 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00028: val_loss improved from 0.04526 to 0.04339, saving model to deep_model3flipped_loss.hdf5
# Epoch 29/100
# 49/49 [==============================] - 3s 71ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00029: val_loss improved from 0.04339 to 0.04170, saving model to deep_model3flipped_loss.hdf5
# Epoch 30/100
# 49/49 [==============================] - 4s 72ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0402 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00030: val_loss improved from 0.04170 to 0.04015, saving model to deep_model3flipped_loss.hdf5
# Epoch 31/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0387 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00031: val_loss improved from 0.04015 to 0.03874, saving model to deep_model3flipped_loss.hdf5
# Epoch 32/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0374 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00032: val_loss improved from 0.03874 to 0.03742, saving model to deep_model3flipped_loss.hdf5
# Epoch 33/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0362 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00033: val_loss improved from 0.03742 to 0.03621, saving model to deep_model3flipped_loss.hdf5
# Epoch 34/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0351 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00034: val_loss improved from 0.03621 to 0.03508, saving model to deep_model3flipped_loss.hdf5
# Epoch 35/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0340 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00035: val_loss improved from 0.03508 to 0.03404, saving model to deep_model3flipped_loss.hdf5
# Epoch 36/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0331 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00036: val_loss improved from 0.03404 to 0.03307, saving model to deep_model3flipped_loss.hdf5
# Epoch 37/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0322 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00037: val_loss improved from 0.03307 to 0.03218, saving model to deep_model3flipped_loss.hdf5
# Epoch 38/100
# 49/49 [==============================] - 4s 75ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0313 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00038: val_loss improved from 0.03218 to 0.03134, saving model to deep_model3flipped_loss.hdf5
# Epoch 39/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0306 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00039: val_loss improved from 0.03134 to 0.03055, saving model to deep_model3flipped_loss.hdf5
# Epoch 40/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0298 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00040: val_loss improved from 0.03055 to 0.02981, saving model to deep_model3flipped_loss.hdf5
# Epoch 41/100
# 49/49 [==============================] - 4s 74ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00041: val_loss improved from 0.02981 to 0.02911, saving model to deep_model3flipped_loss.hdf5
# Epoch 42/100
# 49/49 [==============================] - 4s 73ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0284 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00042: val_loss improved from 0.02911 to 0.02844, saving model to deep_model3flipped_loss.hdf5
# Epoch 43/100
# 49/49 [==============================] - 4s 73ms/step - loss: 9.6813e-04 - accuracy: 1.0000 - val_loss: 0.0278 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00043: val_loss improved from 0.02844 to 0.02782, saving model to deep_model3flipped_loss.hdf5
# Epoch 44/100
# 49/49 [==============================] - 4s 72ms/step - loss: 8.9784e-04 - accuracy: 1.0000 - val_loss: 0.0272 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00044: val_loss improved from 0.02782 to 0.02722, saving model to deep_model3flipped_loss.hdf5
# Epoch 45/100
# 49/49 [==============================] - 4s 72ms/step - loss: 8.3411e-04 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00045: val_loss improved from 0.02722 to 0.02665, saving model to deep_model3flipped_loss.hdf5
# Epoch 46/100
# 49/49 [==============================] - 4s 76ms/step - loss: 7.7612e-04 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00046: val_loss improved from 0.02665 to 0.02611, saving model to deep_model3flipped_loss.hdf5
# Epoch 47/100
# 49/49 [==============================] - 4s 73ms/step - loss: 7.2330e-04 - accuracy: 1.0000 - val_loss: 0.0256 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00047: val_loss improved from 0.02611 to 0.02560, saving model to deep_model3flipped_loss.hdf5
# Epoch 48/100
# 49/49 [==============================] - 4s 74ms/step - loss: 6.7507e-04 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00048: val_loss improved from 0.02560 to 0.02511, saving model to deep_model3flipped_loss.hdf5
# Epoch 49/100
# 49/49 [==============================] - 4s 74ms/step - loss: 6.3094e-04 - accuracy: 1.0000 - val_loss: 0.0246 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00049: val_loss improved from 0.02511 to 0.02464, saving model to deep_model3flipped_loss.hdf5
# Epoch 50/100
# 49/49 [==============================] - 4s 73ms/step - loss: 5.9045e-04 - accuracy: 1.0000 - val_loss: 0.0242 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00050: val_loss improved from 0.02464 to 0.02419, saving model to deep_model3flipped_loss.hdf5
# Epoch 51/100
# 49/49 [==============================] - 4s 74ms/step - loss: 5.5328e-04 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00051: val_loss improved from 0.02419 to 0.02376, saving model to deep_model3flipped_loss.hdf5
# Epoch 52/100
# 49/49 [==============================] - 4s 75ms/step - loss: 5.1906e-04 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00052: val_loss improved from 0.02376 to 0.02335, saving model to deep_model3flipped_loss.hdf5
# Epoch 53/100
# 49/49 [==============================] - 4s 74ms/step - loss: 4.8751e-04 - accuracy: 1.0000 - val_loss: 0.0229 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00053: val_loss improved from 0.02335 to 0.02295, saving model to deep_model3flipped_loss.hdf5
# Epoch 54/100
# 49/49 [==============================] - 4s 73ms/step - loss: 4.5837e-04 - accuracy: 1.0000 - val_loss: 0.0226 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00054: val_loss improved from 0.02295 to 0.02257, saving model to deep_model3flipped_loss.hdf5
# Epoch 55/100
# 49/49 [==============================] - 4s 75ms/step - loss: 4.3142e-04 - accuracy: 1.0000 - val_loss: 0.0222 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00055: val_loss improved from 0.02257 to 0.02220, saving model to deep_model3flipped_loss.hdf5
# Epoch 56/100
# 49/49 [==============================] - 4s 74ms/step - loss: 4.0647e-04 - accuracy: 1.0000 - val_loss: 0.0218 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00056: val_loss improved from 0.02220 to 0.02185, saving model to deep_model3flipped_loss.hdf5
# Epoch 57/100
# 49/49 [==============================] - 4s 72ms/step - loss: 3.8331e-04 - accuracy: 1.0000 - val_loss: 0.0215 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00057: val_loss improved from 0.02185 to 0.02151, saving model to deep_model3flipped_loss.hdf5
# Epoch 58/100
# 49/49 [==============================] - 4s 76ms/step - loss: 3.6182e-04 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00058: val_loss improved from 0.02151 to 0.02118, saving model to deep_model3flipped_loss.hdf5
# Epoch 59/100
# 49/49 [==============================] - 4s 74ms/step - loss: 3.4182e-04 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00059: val_loss improved from 0.02118 to 0.02086, saving model to deep_model3flipped_loss.hdf5
# Epoch 60/100
# 49/49 [==============================] - 4s 74ms/step - loss: 3.2320e-04 - accuracy: 1.0000 - val_loss: 0.0206 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00060: val_loss improved from 0.02086 to 0.02055, saving model to deep_model3flipped_loss.hdf5
# Epoch 61/100
# 49/49 [==============================] - 4s 74ms/step - loss: 3.0584e-04 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00061: val_loss improved from 0.02055 to 0.02025, saving model to deep_model3flipped_loss.hdf5
# Epoch 62/100
# 49/49 [==============================] - 4s 75ms/step - loss: 2.8962e-04 - accuracy: 1.0000 - val_loss: 0.0200 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00062: val_loss improved from 0.02025 to 0.01997, saving model to deep_model3flipped_loss.hdf5
# Epoch 63/100
# 49/49 [==============================] - 4s 75ms/step - loss: 2.7447e-04 - accuracy: 1.0000 - val_loss: 0.0197 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00063: val_loss improved from 0.01997 to 0.01969, saving model to deep_model3flipped_loss.hdf5
# Epoch 64/100
# 49/49 [==============================] - 4s 76ms/step - loss: 2.6028e-04 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00064: val_loss improved from 0.01969 to 0.01942, saving model to deep_model3flipped_loss.hdf5
# Epoch 65/100
# 49/49 [==============================] - 4s 73ms/step - loss: 2.4700e-04 - accuracy: 1.0000 - val_loss: 0.0192 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00065: val_loss improved from 0.01942 to 0.01915, saving model to deep_model3flipped_loss.hdf5
# Epoch 66/100
# 49/49 [==============================] - 3s 71ms/step - loss: 2.3454e-04 - accuracy: 1.0000 - val_loss: 0.0189 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00066: val_loss improved from 0.01915 to 0.01890, saving model to deep_model3flipped_loss.hdf5
# Epoch 67/100
# 49/49 [==============================] - 4s 74ms/step - loss: 2.2286e-04 - accuracy: 1.0000 - val_loss: 0.0187 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00067: val_loss improved from 0.01890 to 0.01865, saving model to deep_model3flipped_loss.hdf5
# Epoch 68/100
# 49/49 [==============================] - 4s 75ms/step - loss: 2.1187e-04 - accuracy: 1.0000 - val_loss: 0.0184 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00068: val_loss improved from 0.01865 to 0.01841, saving model to deep_model3flipped_loss.hdf5
# Epoch 69/100
# 49/49 [==============================] - 4s 75ms/step - loss: 2.0154e-04 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00069: val_loss improved from 0.01841 to 0.01817, saving model to deep_model3flipped_loss.hdf5
# Epoch 70/100
# 49/49 [==============================] - 4s 72ms/step - loss: 1.9182e-04 - accuracy: 1.0000 - val_loss: 0.0179 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00070: val_loss improved from 0.01817 to 0.01795, saving model to deep_model3flipped_loss.hdf5
# Epoch 71/100
# 49/49 [==============================] - 4s 74ms/step - loss: 1.8266e-04 - accuracy: 1.0000 - val_loss: 0.0177 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00071: val_loss improved from 0.01795 to 0.01772, saving model to deep_model3flipped_loss.hdf5
# Epoch 72/100
# 49/49 [==============================] - 4s 74ms/step - loss: 1.7402e-04 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00072: val_loss improved from 0.01772 to 0.01751, saving model to deep_model3flipped_loss.hdf5
# Epoch 73/100
# 49/49 [==============================] - 4s 74ms/step - loss: 1.6587e-04 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00073: val_loss improved from 0.01751 to 0.01730, saving model to deep_model3flipped_loss.hdf5
# Epoch 74/100
# 49/49 [==============================] - 4s 74ms/step - loss: 1.5816e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00074: val_loss improved from 0.01730 to 0.01709, saving model to deep_model3flipped_loss.hdf5
# Epoch 75/100
# 49/49 [==============================] - 4s 72ms/step - loss: 1.5088e-04 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00075: val_loss improved from 0.01709 to 0.01688, saving model to deep_model3flipped_loss.hdf5
# Epoch 76/100
# 49/49 [==============================] - 4s 73ms/step - loss: 1.4399e-04 - accuracy: 1.0000 - val_loss: 0.0167 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00076: val_loss improved from 0.01688 to 0.01668, saving model to deep_model3flipped_loss.hdf5
# Epoch 77/100
# 49/49 [==============================] - 4s 73ms/step - loss: 1.3748e-04 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00077: val_loss improved from 0.01668 to 0.01649, saving model to deep_model3flipped_loss.hdf5
# Epoch 78/100
# 49/49 [==============================] - 4s 75ms/step - loss: 1.3130e-04 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00078: val_loss improved from 0.01649 to 0.01630, saving model to deep_model3flipped_loss.hdf5
# Epoch 00078: early stopping
# The End

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.show()

# %%
predictions = Dense(2,activation='softmax')(deep_net)
model_2 = Model(inputs=inputsin, outputs=predictions)

model_2.load_weights("deep_model3flipped_loss.hdf5")

# %%
pre = deep_model.predict(test_data)
pre_2 = model_2.predict(test_data)

# %%
res = []
for p in pre:
  if p[0] > p[1]:
    res.append([0, 1])
  else:
    res.append([1, 0])

res_2 = []
for p in pre_2:
  if p[0] > p[1]:
    res_2.append([0, 1])
  else:
    res_2.append([1, 0])

# %%
corr = 0
for i in range(len(test_label)):
  #print(int(test_label[i]), res[i])
  if res[i][int(test_label[i])] == 1:
    #print('yes')
    corr += 1
print(corr)
# Out:
# 10

# %%
corr = 0
for i in range(len(test_label)):
  #print(int(test_label[i]), res[i])
  if res_2[i][int(test_label[i])] == 1:
    #print('yes')
    corr += 1
print(corr)
# Out:
# 10

# %%
res = []
for p in pre:
  if p[1] < 0.025:
    res.append([1, 0])
  else:
    res.append([0, 1])

res_2 = []
for p in pre_2:
  if p[1] < 0.025:
    res_2.append([1, 0])
  else:
    res_2.append([0, 1])

# %%
corr = 0
for i in range(len(test_label)):
  #print(int(test_label[i]), res[i])
  if res[i][int(test_label[i])] == 1:
    #print('yes')
    corr += 1
print(corr)

corr = 0
for i in range(len(test_label)):
  #print(int(test_label[i]), res[i])
  if res_2[i][int(test_label[i])] == 1:
    #print('yes')
    corr += 1
print(corr)
# Out:
# 43
# 43

# %% [markdown]
# # 4 bit quantization

# %%
! pip uninstall -y tensorflow
! pip install -q tf-nightly
! pip install -q tensorflow-model-optimization
# Out:
# WARNING: Skipping tensorflow as it is not installed.

# %%
import tensorflow as tf
import tensorflow_model_optimization as tfmot

import tempfile

# %%
LastValueQuantizer = tfmot.quantization.keras.quantizers.LastValueQuantizer
MovingAverageQuantizer = tfmot.quantization.keras.quantizers.MovingAverageQuantizer

class DefaultDenseQuantizeConfig(tfmot.quantization.keras.QuantizeConfig):
    # Configure how to quantize weights.
    def get_weights_and_quantizers(self, layer):
      return [(layer.kernel, LastValueQuantizer(num_bits=8, symmetric=True, narrow_range=False, per_axis=False))]

    # Configure how to quantize activations.
    def get_activations_and_quantizers(self, layer):
      return [(layer.activation, MovingAverageQuantizer(num_bits=8, symmetric=False, narrow_range=False, per_axis=False))]

    def set_quantize_weights(self, layer, quantize_weights):
      # Add this line for each item returned in `get_weights_and_quantizers`
      # , in the same order
      layer.kernel = quantize_weights[0]

    def set_quantize_activations(self, layer, quantize_activations):
      # Add this line for each item returned in `get_activations_and_quantizers`
      # , in the same order.
      layer.activation = quantize_activations[0]

    # Configure how to quantize outputs (may be equivalent to activations).
    def get_output_quantizers(self, layer):
      return []

    def get_config(self):
      return {}

# %%
class ModifiedDenseQuantizeConfig(DefaultDenseQuantizeConfig):
    # Configure weights to quantize with 4-bit instead of 8-bits.
    def get_weights_and_quantizers(self, layer):
      return [(layer.kernel, MovingAverageQuantizer(num_bits=4, symmetric=True, narrow_range=False, per_axis=False))]
    
    
    def get_activations_and_quantizers(self, layer):
      return [(layer.activation, MovingAverageQuantizer(num_bits=4, symmetric=False, narrow_range=False, per_axis=False))]

# %%
quantize_annotate_layer = tfmot.quantization.keras.quantize_annotate_layer
quantize_annotate_model = tfmot.quantization.keras.quantize_annotate_model
quantize_scope = tfmot.quantization.keras.quantize_scope

# %%
from pdb import set_trace
#import mne
import pandas as pd
import numpy as np
import math
import os
import h5py
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN,LSTM, Dense, Activation, Bidirectional
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Convolution2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import MaxPooling3D
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping


# ----------------------DEEP-NET Testing-----------------------
from tensorflow.keras.layers import Input,Dense,concatenate,Flatten,GRU,Conv1D,Conv2D
from tensorflow.keras.models import Model


# Making a deep net


inputsin= Input(shape=(t,f))


# ------------------First Inception
deep_net = Conv1D(25, 10, strides=1, activation='relu',padding="causal")(inputsin)
deep_net = MaxPooling1D(3, 3, padding="same")(deep_net)

deep_net = Conv1D(50, 10, activation='relu', padding='causal')(deep_net)
deep_net = MaxPooling1D(3, 3, padding='same')(deep_net)

deep_net = Conv1D(100, 10, activation='relu', padding='causal')(deep_net)
deep_net = MaxPooling1D(3, 3, padding='same')(deep_net)

deep_net = Conv1D(200, 10, activation='relu', padding='causal')(deep_net)
deep_net = MaxPooling1D(3, 3, padding='same')(deep_net)

deep_net = Flatten()(deep_net)
predictions = Dense(2,activation='softmax')(deep_net)


deep_model = Model(inputs=inputsin, outputs=predictions)

# compiling model
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001)
deep_model.compile(optimizer = adam_optimizer, loss = 'categorical_crossentropy', metrics=['accuracy'])



# early stopping
es = EarlyStopping(monitor='val_loss', min_delta=0.01, mode='min', verbose=1, patience=25)                                # patience
mc = ModelCheckpoint('deep_model3flipped_acc.hdf5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)        # filepath (save model as)
mces = ModelCheckpoint('deep_model3flipped_loss.hdf5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)    # filepath (save model as)

deep_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 22, 15000)]       0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 22, 25)            3750025
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 8, 25)             0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 8, 50)             12550
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 3, 50)             0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 3, 100)            50100
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1, 100)            0
# _________________________________________________________________
# conv1d_7 (Conv1D)            (None, 1, 200)            200200
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 200)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 200)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 4,013,277
# Trainable params: 4,013,277
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Helper function uses `quantize_annotate_layer` to annotate that only the 
# Dense layers should be quantized.
def apply_quantization(layer):
  if isinstance(layer, tf.keras.layers.Dense) or isinstance(layer, tf.keras.layers.Conv1D):
    return tfmot.quantization.keras.quantize_annotate_layer(layer, ModifiedDenseQuantizeConfig())
  return layer

annotated_model = tf.keras.models.clone_model(
    deep_model,
    clone_function=apply_quantization,
)

# %%
with quantize_scope(
  {'ModifiedDenseQuantizeConfig': ModifiedDenseQuantizeConfig}):
  # Use `quantize_apply` to actually make the model quantization aware.
  quant_aware_model = tfmot.quantization.keras.quantize_apply(annotated_model)

quant_aware_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 22, 15000)]       0
# _________________________________________________________________
# quantize_layer (QuantizeLaye (None, 22, 15000)         3
# _________________________________________________________________
# quant_conv1d_4 (QuantizeWrap (None, 22, 25)            3750030
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 8, 25)             0
# _________________________________________________________________
# quant_conv1d_5 (QuantizeWrap (None, 8, 50)             12555
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 3, 50)             0
# _________________________________________________________________
# quant_conv1d_6 (QuantizeWrap (None, 3, 100)            50105
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1, 100)            0
# _________________________________________________________________
# quant_conv1d_7 (QuantizeWrap (None, 1, 200)            200205
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 200)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 200)               0
# _________________________________________________________________
# quant_dense_1 (QuantizeWrapp (None, 2)                 407
# =================================================================
# Total params: 4,013,305
# Trainable params: 4,013,277
# Non-trainable params: 28
# _________________________________________________________________

# %%
# learning rate to 0.00001
adam_optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001)

quant_aware_model.compile(optimizer = adam_optimizer, loss = 'categorical_crossentropy', metrics=['accuracy'])
print(quant_aware_model.metrics_names)
print(quant_aware_model.summary())

# fit model
hist=quant_aware_model.fit(eval_data,eval_label,validation_split=0.1, epochs=100,batch_size=64,verbose=1,callbacks=[es, mc,mces],shuffle=False) #epochs #split #
print('The End')
# Out:
# []
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 22, 15000)]       0
# _________________________________________________________________
# quantize_layer (QuantizeLaye (None, 22, 15000)         3
# _________________________________________________________________
# quant_conv1d_4 (QuantizeWrap (None, 22, 25)            3750030
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 8, 25)             0
# _________________________________________________________________
# quant_conv1d_5 (QuantizeWrap (None, 8, 50)             12555
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 3, 50)             0
# _________________________________________________________________
# quant_conv1d_6 (QuantizeWrap (None, 3, 100)            50105
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 1, 100)            0
# _________________________________________________________________
# quant_conv1d_7 (QuantizeWrap (None, 1, 200)            200205
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 1, 200)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 200)               0
# _________________________________________________________________
# quant_dense_1 (QuantizeWrapp (None, 2)                 407
# =================================================================
# Total params: 4,013,305
# Trainable params: 4,013,277
# Non-trainable params: 28
# _________________________________________________________________
# None
# Epoch 1/100
# 49/49 [==============================] - 37s 108ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00001: val_loss improved from inf to 0.69315, saving model to deep_model3flipped_loss.hdf5
# Epoch 2/100
# 49/49 [==============================] - 3s 56ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00002: val_loss did not improve from 0.69315
# Epoch 3/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00003: val_loss did not improve from 0.69315
# Epoch 4/100
# 49/49 [==============================] - 3s 57ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00004: val_loss did not improve from 0.69315
# Epoch 5/100
# 49/49 [==============================] - 3s 56ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00005: val_loss did not improve from 0.69315
# Epoch 6/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00006: val_loss did not improve from 0.69315
# Epoch 7/100
# 49/49 [==============================] - 3s 57ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00007: val_loss did not improve from 0.69315
# Epoch 8/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00008: val_loss did not improve from 0.69315
# Epoch 9/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00009: val_loss did not improve from 0.69315
# Epoch 10/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00010: val_loss did not improve from 0.69315
# Epoch 11/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00011: val_loss did not improve from 0.69315
# Epoch 12/100
# 49/49 [==============================] - 3s 57ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00012: val_loss did not improve from 0.69315
# Epoch 13/100
# 49/49 [==============================] - 3s 56ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00013: val_loss did not improve from 0.69315
# Epoch 14/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00014: val_loss did not improve from 0.69315
# Epoch 15/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00015: val_loss did not improve from 0.69315
# Epoch 16/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00016: val_loss did not improve from 0.69315
# Epoch 17/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00017: val_loss did not improve from 0.69315
# Epoch 18/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00018: val_loss did not improve from 0.69315
# Epoch 19/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00019: val_loss did not improve from 0.69315
# Epoch 20/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00020: val_loss did not improve from 0.69315
# Epoch 21/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00021: val_loss did not improve from 0.69315
# Epoch 22/100
# 49/49 [==============================] - 3s 54ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00022: val_loss did not improve from 0.69315
# Epoch 23/100
# 49/49 [==============================] - 3s 56ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00023: val_loss did not improve from 0.69315
# Epoch 24/100
# 49/49 [==============================] - 3s 53ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00024: val_loss did not improve from 0.69315
# Epoch 25/100
# 49/49 [==============================] - 3s 56ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00025: val_loss did not improve from 0.69315
# Epoch 26/100
# 49/49 [==============================] - 3s 55ms/step - loss: 0.6931 - accuracy: 0.5134 - val_loss: 0.6931 - val_accuracy: 0.5100
# WARNING:tensorflow:Can save best model only with val_acc available, skipping.
#
# Epoch 00026: val_loss did not improve from 0.69315
# Epoch 00026: early stopping
# The End

# %%
np.to_array(quant_aware_model.layers[2].weights[1].value)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-8cb0822deeca> in <module>()
# ----> 1 np.to_array(quant_aware_model.layers[2].weights[1].value)
#
# /usr/local/lib/python3.7/dist-packages/numpy/__init__.py in __getattr__(attr)
#     213             else:
#     214                 raise AttributeError("module {!r} has no attribute "
# --> 215                                      "{!r}".format(__name__, attr))
#     216
#     217         def __dir__():
#
# AttributeError: module 'numpy' has no attribute 'to_array'

# %%
import matplotlib.pyplot as plt

plt.plot(quant_aware_model.layers[2].weights[1].flatten())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-4e6bc1dae5c1> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(quant_aware_model.layers[2].weights[1].flatten())
#
# AttributeError: 'ResourceVariable' object has no attribute 'flatten'
